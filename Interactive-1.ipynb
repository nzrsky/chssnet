# %% [markdown]
# Connected to Python 3.11.3

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json

# Enable caching
requests_cache.install_cache('html_cache')

# URL to fetch HTML from
url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

# Fetch the HTML content
response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
else:
    html_content = ''
    print(f"Failed to retrieve content. Status Code: {response.status_code}")

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Initialize the JSON structure
parsed_data = {}

# Find all filter categories
filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

for category in filter_categories:
    # Extract the category name
    category_name_span = category.find("span")
    if category_name_span:
        category_name = category_name_span.get_text(strip=True)

        # Extract subitems for this category
        subitems = []
        for label in category.find_all("label", class_="form-control form-control-checkbox"):
            subitem = label.get_text(strip=True).split(" ")[0]  # Split to get the first word only
            subitems.append(subitem)

        # Add category and its subitems to the parsed data
        parsed_data[category_name] = subitems

# Convert to JSON
json_data = json.dumps(parsed_data, ensure_ascii=False)
print(json_data)
# Out:
# {"Наличие в магазинах": ["Товар"], "Цена, €": [], "Производители": ["Leifheit15", "Jata6", "Tefal3", "Zelmer2"], "Материал основы гладильной доски": ["Металл0", "Термопластик0"], "Размеры зоны глажки": ["107", "110", "116", "118", "120", "124", "130", "130", "130", "137", "95"]}

# %% [markdown]
# _Restarting Python 3.11.3..._

# %% [markdown]
# Restarted Python 3.11.3

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json

# Enable caching
requests_cache.install_cache('html_cache')

# URL to fetch HTML from
url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

# Fetch the HTML content
response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
else:
    html_content = ''
    print(f"Failed to retrieve content. Status Code: {response.status_code}")

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Initialize the JSON structure
parsed_data = {}

# Find all filter categories
filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

for category in filter_categories:
    # Extract the category name
    category_name_span = category.find("span")
    if category_name_span:
        category_name = category_name_span.get_text(strip=True)

        # Extract subitems for this category
        subitems = []
        for label in category.find_all("label", class_="form-control form-control-checkbox"):
            # Remove <small> tags and their content
            for small_tag in label.find_all('small'):
                small_tag.decompose()

            subitem = label.get_text(strip=True).split(" ")[0]  # Split to get the first word only
            subitems.append(subitem)

        # Add category and its subitems to the parsed data
        parsed_data[category_name] = subitems

# Convert to JSON
json_data = json.dumps(parsed_data, ensure_ascii=False)
print(json_data)
# Out:
# {"Наличие в магазинах": ["Товар"], "Цена, €": [], "Производители": ["Leifheit", "Jata", "Tefal", "Zelmer"], "Материал основы гладильной доски": ["Металл", "Термопластик"], "Размеры зоны глажки": ["107", "110", "116", "118", "120", "124", "130", "130", "130", "137", "95"]}

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json

# Enable caching
requests_cache.install_cache('html_cache')

# URL to fetch HTML from
url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

# Fetch the HTML content
response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
else:
    html_content = ''
    print(f"Failed to retrieve content. Status Code: {response.status_code}")

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Initialize the JSON structure
parsed_data = {}

# Find all filter categories
filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

for category in filter_categories:
    # Extract the category name
    category_name_span = category.find("span")
    if category_name_span:
        category_name = category_name_span.get_text(strip=True)

        # Extract subitems for this category
        subitems = []
        for label in category.find_all("label", class_="form-control form-control-checkbox"):
            # Remove <small> tags and their content
            for small_tag in label.find_all('small'):
                small_tag.decompose()

            # Extract the full text
            subitem = label.get_text(strip=True)
            subitems.append(subitem)

        # Add category and its subitems to the parsed data
        parsed_data[category_name] = subitems

# Convert to JSON
json_data = json.dumps(parsed_data, ensure_ascii=False)
print(json_data)
# Out:
# {"Наличие в магазинах": ["Товар есть на месте"], "Цена, €": [], "Производители": ["Leifheit", "Jata", "Tefal", "Zelmer"], "Материал основы гладильной доски": ["Металл", "Термопластик"], "Размеры зоны глажки": ["107 x 34 см", "110 x 30 см", "116 x 35 см", "118 x 38 см", "120 x 38 см", "124 x 40 см", "130 x 38 см", "130 x 45 см", "130 x 47 см", "137 x 45 см", "95 x 34 см"]}

# %% [markdown]
# _Restarting Python 3.11.3..._

# %% [markdown]
# Restarted Python 3.11.3

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache')


def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1002)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///Users/nazaroff/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py?line=484'>485</a> try:
# --> <a href='file:///Users/nazaroff/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py?line=485'>486</a>     resp = conn.urlopen(
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache')


def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)
# Out:
# Monitori
# Stacionārie datori
# Planšetdatori
# Portatīvie datori
# Lāzerprinteri
# Tintes printeri
# Skeneri
# Tintes printeri (daudzfunkciju)
# Kārtridži (tintes)
# Ārējie cietie diski
# E-grāmatu lasītāji
# Rūteri, tīkla iekārtas
# Spēļu konsoles
# Datorpeles
# Datora klaviatūras
# Datoru skaļruņi
# Datoru somas
# USB flash
# WEB kameras
#
# DVD/CD diski
# Mikrofoni datoram
#
#
# Digitālās fotokameras
# Spoguļkameras
# Videokameras
# Atmiņas kartes
# Foto somas
# Lādētāji foto un video tehnikai
# Foto statīvi
# Televizori
# Projektori
# TV kronšteini
# Mājas kinozāles
# DVD atskaņotāji
# Blu-ray atskaņotāji
# Mūzikas centri
# MP3 un MP4 atskaņotāji
# Austiņas
# Mikrofoni
# Universālās pultis
# Multimediju atskaņotāji
# Pastiprinātāji
# Skaļruņi un sabvūferi
# Radio uztvērēji
#
#
# Ledusskapji
# Saldētavas
# Vīna skapji
# Veļas mašīnas
# Veļas žāvētāji
# Trauku mazgājamās mašīnas
# Plītis
# Boileri
#
# Iebūvējamie ledusskapji
# Iebūvējamās saldētavas
# Iebūvējamās veļas mašīnas
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache')


def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)

with open('rd_output.json', 'w', encoding='utf-8') as file:
    json.dump(final_data, file, ensure_ascii=False, indent=4)
# Out:
# Monitori
# Stacionārie datori
# Planšetdatori
# Portatīvie datori
# Lāzerprinteri
# Tintes printeri
# Skeneri
# Tintes printeri (daudzfunkciju)
# Kārtridži (tintes)
# Ārējie cietie diski
# E-grāmatu lasītāji
# Rūteri, tīkla iekārtas
# Spēļu konsoles
# Datorpeles
# Datora klaviatūras
# Datoru skaļruņi
# Datoru somas
# USB flash
# WEB kameras
#
# DVD/CD diski
# Mikrofoni datoram
#
#
# Digitālās fotokameras
# Spoguļkameras
# Videokameras
# Atmiņas kartes
# Foto somas
# Lādētāji foto un video tehnikai
# Foto statīvi
# Televizori
# Projektori
# TV kronšteini
# Mājas kinozāles
# DVD atskaņotāji
# Blu-ray atskaņotāji
# Mūzikas centri
# MP3 un MP4 atskaņotāji
# Austiņas
# Mikrofoni
# Universālās pultis
# Multimediju atskaņotāji
# Pastiprinātāji
# Skaļruņi un sabvūferi
# Radio uztvērēji
#
#
# Ledusskapji
# Saldētavas
# Vīna skapji
# Veļas mašīnas
# Veļas žāvētāji
# Trauku mazgājamās mašīnas
# Plītis
# Boileri
#
# Iebūvējamie ledusskapji
# Iebūvējamās saldētavas
# Iebūvējamās veļas mašīnas
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache')


def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)

with open('rd_output.json', 'w', encoding='utf-8') as file:
    json.dump(final_data, file, ensure_ascii=False, indent=4)
# Out:
# Monitori
# Stacionārie datori
# Planšetdatori
# Portatīvie datori
# Lāzerprinteri
# Tintes printeri
# Skeneri
# Tintes printeri (daudzfunkciju)
# Kārtridži (tintes)
# Ārējie cietie diski
# E-grāmatu lasītāji
# Rūteri, tīkla iekārtas
# Spēļu konsoles
# Datorpeles
# Datora klaviatūras
# Datoru skaļruņi
# Datoru somas
# USB flash
# WEB kameras
#
# DVD/CD diski
# Mikrofoni datoram
#
#
# Digitālās fotokameras
# Spoguļkameras
# Videokameras
# Atmiņas kartes
# Foto somas
# Lādētāji foto un video tehnikai
# Foto statīvi
# Televizori
# Projektori
# TV kronšteini
# Mājas kinozāles
# DVD atskaņotāji
# Blu-ray atskaņotāji
# Mūzikas centri
# MP3 un MP4 atskaņotāji
# Austiņas
# Mikrofoni
# Universālās pultis
# Multimediju atskaņotāji
# Pastiprinātāji
# Skaļruņi un sabvūferi
# Radio uztvērēji
#
#
# Ledusskapji
# Saldētavas
# Vīna skapji
# Veļas mašīnas
# Veļas žāvētāji
# Trauku mazgājamās mašīnas
# Plītis
# Boileri
#
# Iebūvējamie ledusskapji
# Iebūvējamās saldētavas
# Iebūvējamās veļas mašīnas
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)

with open('rd_output.json', 'w', encoding='utf-8') as file:
    json.dump(final_data, file, ensure_ascii=False, indent=4)
# Out:
# Monitori
# Stacionārie datori
# Planšetdatori
# Portatīvie datori
# Lāzerprinteri
# Tintes printeri
# Skeneri
# Tintes printeri (daudzfunkciju)
# Kārtridži (tintes)
# Ārējie cietie diski
# E-grāmatu lasītāji
# Rūteri, tīkla iekārtas
# Spēļu konsoles
# Datorpeles
# Datora klaviatūras
# Datoru skaļruņi
# Datoru somas
# USB flash
# WEB kameras
#
# DVD/CD diski
# Mikrofoni datoram
#
#
# Digitālās fotokameras
# Spoguļkameras
# Videokameras
# Atmiņas kartes
# Foto somas
# Lādētāji foto un video tehnikai
# Foto statīvi
# Televizori
# Projektori
# TV kronšteini
# Mājas kinozāles
# DVD atskaņotāji
# Blu-ray atskaņotāji
# Mūzikas centri
# MP3 un MP4 atskaņotāji
# Austiņas
# Mikrofoni
# Universālās pultis
# Multimediju atskaņotāji
# Pastiprinātāji
# Skaļruņi un sabvūferi
# Radio uztvērēji
#
#
# Ledusskapji
# Saldētavas
# Vīna skapji
# Veļas mašīnas
# Veļas žāvētāji
# Trauku mazgājamās mašīnas
# Plītis
# Boileri
#
# Iebūvējamie ledusskapji
# Iebūvējamās saldētavas
# Iebūvējamās veļas mašīnas
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    return json_data, title

final_data = {}

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)
        print(title)

# Convert to JSON
json_data = json.dumps(final_data, ensure_ascii=False)
print(json_data)

with open('rd_output.json', 'w', encoding='utf-8') as file:
    json.dump(final_data, file, ensure_ascii=False, indent=4)
# Out:
# Monitori
# Stacionārie datori
# Planšetdatori
# Portatīvie datori
# Lāzerprinteri
# Tintes printeri
# Skeneri
# Tintes printeri (daudzfunkciju)
# Kārtridži (tintes)
# Ārējie cietie diski
# E-grāmatu lasītāji
# Rūteri, tīkla iekārtas
# Spēļu konsoles
# Datorpeles
# Datora klaviatūras
# Datoru skaļruņi
# Datoru somas
# USB flash
# WEB kameras
#
# DVD/CD diski
# Mikrofoni datoram
#
#
# Digitālās fotokameras
# Spoguļkameras
# Videokameras
# Atmiņas kartes
# Foto somas
# Lādētāji foto un video tehnikai
# Foto statīvi
# Televizori
# Projektori
# TV kronšteini
# Mājas kinozāles
# DVD atskaņotāji
# Blu-ray atskaņotāji
# Mūzikas centri
# MP3 un MP4 atskaņotāji
# Austiņas
# Mikrofoni
# Universālās pultis
# Multimediju atskaņotāji
# Pastiprinātāji
# Skaļruņi un sabvūferi
# Radio uztvērēji
#
#
# Ledusskapji
# Saldētavas
# Vīna skapji
# Veļas mašīnas
# Veļas žāvētāji
# Trauku mazgājamās mašīnas
# Plītis
# Boileri
#
# Iebūvējamie ledusskapji
# Iebūvējamās saldētavas
# Iebūvējamās veļas mašīnas
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'http://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)
        
    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# No data in
#  - 0.00% complete
# Monitori - 0.00% complete
# Stacionārie datori - 0.00% complete
# Planšetdatori - 0.00% complete
# Portatīvie datori - 0.00% complete
# Lāzerprinteri - 0.00% complete
# Tintes printeri - 0.00% complete
# Skeneri - 0.00% complete
# Tintes printeri (daudzfunkciju) - 0.01% complete
# Kārtridži (tintes) - 0.01% complete
# Ārējie cietie diski - 0.01% complete
# E-grāmatu lasītāji - 0.01% complete
# Rūteri, tīkla iekārtas - 0.01% complete
# Spēļu konsoles - 0.01% complete
# Datorpeles - 0.01% complete
# Datora klaviatūras - 0.01% complete
# Datoru skaļruņi - 0.01% complete
# Datoru somas - 0.01% complete
# USB flash - 0.01% complete
# WEB kameras - 0.01% complete
# No data in
#  - 0.01% complete
# DVD/CD diski - 0.01% complete
# Mikrofoni datoram - 0.01% complete
# No data in
#  - 0.01% complete
# No data in
# Digitālās fotokameras - 0.02% complete
# Spoguļkameras - 0.02% complete
# Videokameras - 0.02% complete
# Atmiņas kartes - 0.02% complete
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'http://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)
        
    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# No data in
#  - 0.00% complete
# Monitori - 0.00% complete
# Stacionārie datori - 0.00% complete
# Planšetdatori - 0.00% complete
# Portatīvie datori - 0.00% complete
# Lāzerprinteri - 0.00% complete
# Tintes printeri - 0.00% complete
# Skeneri - 0.00% complete
# Tintes printeri (daudzfunkciju) - 0.01% complete
# Kārtridži (tintes) - 0.01% complete
# Ārējie cietie diski - 0.01% complete
# E-grāmatu lasītāji - 0.01% complete
# Rūteri, tīkla iekārtas - 0.01% complete
# Spēļu konsoles - 0.01% complete
# Datorpeles - 0.01% complete
# Datora klaviatūras - 0.01% complete
# Datoru skaļruņi - 0.01% complete
# Datoru somas - 0.01% complete
# USB flash - 0.01% complete
# WEB kameras - 0.01% complete
# No data in
#  - 0.01% complete
# DVD/CD diski - 0.01% complete
# Mikrofoni datoram - 0.01% complete
# No data in
#  - 0.01% complete
# No data in
# Digitālās fotokameras - 0.02% complete
# Spoguļkameras - 0.02% complete
# Videokameras - 0.02% complete
# Atmiņas kartes - 0.02% complete
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# No data in
#  - 0.00% complete
# Monitori - 0.00% complete
# Stacionārie datori - 0.00% complete
# Planšetdatori - 0.00% complete
# Portatīvie datori - 0.00% complete
# Lāzerprinteri - 0.00% complete
# Tintes printeri - 0.00% complete
# Skeneri - 0.00% complete
# Tintes printeri (daudzfunkciju) - 0.01% complete
# Kārtridži (tintes) - 0.01% complete
# Ārējie cietie diski - 0.01% complete
# E-grāmatu lasītāji - 0.01% complete
# Rūteri, tīkla iekārtas - 0.01% complete
# Spēļu konsoles - 0.01% complete
# Datorpeles - 0.01% complete
# Datora klaviatūras - 0.01% complete
# Datoru skaļruņi - 0.01% complete
# Datoru somas - 0.01% complete
# USB flash - 0.01% complete
# WEB kameras - 0.01% complete
# No data in
#  - 0.01% complete
# DVD/CD diski - 0.01% complete
# Mikrofoni datoram - 0.01% complete
# No data in
#  - 0.01% complete
# No data in
# Digitālās fotokameras - 0.02% complete
# Spoguļkameras - 0.02% complete
# Videokameras - 0.02% complete
# Atmiņas kartes - 0.02% complete
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# No data in
#  - 0.00% complete
# Monitori - 0.00% complete
# Stacionārie datori - 0.00% complete
# Planšetdatori - 0.00% complete
# Portatīvie datori - 0.00% complete
# Lāzerprinteri - 0.00% complete
# Tintes printeri - 0.00% complete
# Skeneri - 0.00% complete
# Tintes printeri (daudzfunkciju) - 0.01% complete
# Kārtridži (tintes) - 0.01% complete
# Ārējie cietie diski - 0.01% complete
# E-grāmatu lasītāji - 0.01% complete
# Rūteri, tīkla iekārtas - 0.01% complete
# Spēļu konsoles - 0.01% complete
# Datorpeles - 0.01% complete
# Datora klaviatūras - 0.01% complete
# Datoru skaļruņi - 0.01% complete
# Datoru somas - 0.01% complete
# USB flash - 0.01% complete
# WEB kameras - 0.01% complete
# No data in
#  - 0.01% complete
# DVD/CD diski - 0.01% complete
# Mikrofoni datoram - 0.01% complete
# No data in
#  - 0.01% complete
# No data in
# Digitālās fotokameras - 0.02% complete
# Spoguļkameras - 0.02% complete
# Videokameras - 0.02% complete
# Atmiņas kartes - 0.02% complete
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# No data in
#  - 0.00% complete
# Monitori - 0.00% complete
# Stacionārie datori - 0.00% complete
# Planšetdatori - 0.00% complete
# Portatīvie datori - 0.00% complete
# Lāzerprinteri - 0.00% complete
# Tintes printeri - 0.00% complete
# Skeneri - 0.00% complete
# Tintes printeri (daudzfunkciju) - 0.01% complete
# Kārtridži (tintes) - 0.01% complete
# Ārējie cietie diski - 0.01% complete
# E-grāmatu lasītāji - 0.01% complete
# Rūteri, tīkla iekārtas - 0.01% complete
# Spēļu konsoles - 0.01% complete
# Datorpeles - 0.01% complete
# Datora klaviatūras - 0.01% complete
# Datoru skaļruņi - 0.01% complete
# Datoru somas - 0.01% complete
# USB flash - 0.01% complete
# WEB kameras - 0.01% complete
# No data in
#  - 0.01% complete
# DVD/CD diski - 0.01% complete
# Mikrofoni datoram - 0.01% complete
# No data in
#  - 0.01% complete
# No data in
# Digitālās fotokameras - 0.02% complete
# Spoguļkameras - 0.02% complete
# Videokameras - 0.02% complete
# Atmiņas kartes - 0.02% complete
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output

# %export SSL_CERT_FILE=~/.proxyman/proxyman-ca.pem
# %export REQUESTS_CA_BUNDLE=~/.proxyman/proxyman-ca.pem

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# UsageError: Line magic function `%export` not found.

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output
import os

os.environ['SSL_CERT_FILE'] = os.path.expanduser('~/.proxyman/proxyman-ca.pem')
os.environ['REQUESTS_CA_BUNDLE'] = os.path.expanduser('~/.proxyman/proxyman-ca.pem')

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: EOF occurred in violation of protocol (_ssl.c:1002)
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///Users/nazaroff/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py?line=484'>485</a> try:
# ...

# %%
import requests
import requests_cache
from bs4 import BeautifulSoup
import json
import xml.etree.ElementTree as ET
from IPython.display import clear_output
import os

os.environ['SSL_CERT_FILE'] = os.path.expanduser('~/.proxyman/proxyman-ca.pem')
os.environ['REQUESTS_CA_BUNDLE'] = os.path.expanduser('~/.proxyman/proxyman-ca.pem')

# Load and parse the sitemap.xml
tree = ET.parse('rdveikals_sitemap.xml')
root = tree.getroot()

# Initialize a dictionary to hold URLs categorized by language
urls_by_language = {'lv': [], 'ru': []}

for url in root.findall('{http://www.sitemaps.org/schemas/sitemap/0.9}url'):
    loc = url.find('{http://www.sitemaps.org/schemas/sitemap/0.9}loc').text
    # Check if URL is for Latvian (lv) or Russian (ru)
    if '/lv/' in loc:
        urls_by_language['lv'].append(loc)
    elif '/ru/' in loc:
        urls_by_language['ru'].append(loc)

# Enable caching
requests_cache.install_cache('html_cache', filter_fn=lambda response: response.status_code in [200, 404])

proxies = {
    'http': 'http://127.0.0.1:9090',
    'https': 'https://127.0.0.1:9090',
}

def parse_url(url):
    # URL to fetch HTML from
    #url = 'https://www.rdveikals.lv/categories/ru/360/sort/5/filter/0_0_0_0/page/1/%D0%93%D0%BB%D0%B0%D0%B4%D0%B8%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5-%D0%B4%D0%BE%D1%81%D0%BA%D0%B8.html'

    # Fetch the HTML content
    response = requests.get(url, proxies=proxies, verify=False)
    if response.status_code == 200:
        html_content = response.text
    else:
        html_content = ''
        print(f"Failed to retrieve content. Status Code: {response.status_code}")

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize the JSON structure
    parsed_data = {}

    # Find all filter categories
    filter_categories = soup.find_all("div", class_="accordion js-filter-form-group")

    for category in filter_categories:
        # Extract the category name
        category_name_span = category.find("span")
        if category_name_span:
            category_name = category_name_span.get_text(strip=True)

            # Extract subitems for this category
            subitems = []
            for label in category.find_all("label", class_="form-control form-control-checkbox"):
                # Remove <small> tags and their content
                for small_tag in label.find_all('small'):
                    small_tag.decompose()

                # Extract the full text
                subitem = label.get_text(strip=True)
                subitems.append(subitem)

            # Add category and its subitems to the parsed data
            parsed_data[category_name] = subitems

    # Convert to JSON
    json_data = json.dumps(parsed_data, ensure_ascii=False)

    title_tag = soup.find('h1', {'class': 'page-title', 'id': 'page-title'})
    title = title_tag.get_text(strip=True) if title_tag else ''

    if len(parsed_data) == 0:
        print("No data in", title)

    return json_data, title

final_data = {}
total_urls = sum(len(urls) for urls in urls_by_language.values())
processed_urls = 0
last_title = None

for language, urls in urls_by_language.items():
    for url in urls:
        parsed_categories, title = parse_url(url)
        processed_urls += 1
        percentage_complete = (processed_urls / total_urls) * 100

        if language not in final_data:
            final_data[language] = {'title': title, 'categories': []}
        
        final_data[language]['categories'].append(parsed_categories)

        if title != last_title:
            print(f"{title} - {percentage_complete:.2f}% complete")
            last_title = title

# Convert to JSON and save
json_data = json.dumps(final_data, ensure_ascii=False, indent=4)
with open('rd_output.json', 'w', encoding='utf-8') as file:
    file.write(json_data)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: EOF occurred in violation of protocol (_ssl.c:1002)
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1002)')))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///Users/nazaroff/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py?line=484'>485</a> try:
# ...

# %% [markdown]
# No kernel connected
